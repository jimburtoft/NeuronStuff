# %% [markdown]
# # Qwen3-14B + LoRA on AWS Trainium2
#
# This notebook demonstrates running **Qwen3-14B** (text-only, 14.8B parameters) with **LoRA adapters** on AWS Trainium2 using NxD Inference and vLLM.
#
# ## What this notebook does
#
# 1. Downloads Qwen3-14B base model and two public LoRA adapters
# 2. Compiles the model with LoRA support at tp=4 on trn2.3xlarge
# 3. Runs inference using different LoRA adapters
# 4. Benchmarks throughput for each adapter
# 5. Uploads artifacts to HuggingFace for reuse on fresh instances
#
# ## Requirements
#
# - **Instance**: trn2.3xlarge (4 NeuronCores at LNC=2, 64 GB HBM, 16 GB/core)
# - **AMI**: Deep Learning AMI Neuron (Ubuntu 24.04) 20260227
# - **SDK**: Neuron SDK 2.28, NxDI 0.8.x, vLLM-neuron 0.4.1
# - **TP degree**: 4 (3.7 GB/core for model weights, 12.3 GB headroom per 16 GB core)
# - **Precision**: BF16
# - **LNC**: 2 (default, gives 4 logical cores)
#
# ## LoRA Adapters
#
# | Adapter | HuggingFace Repo | Rank | Alpha | Size |
# |---------|-----------------|------|-------|------|
# | Adapter A | `nicoboss/Qwen3-14B-Uncensored-Lora` | 32 | 16 | 514 MB |
# | Adapter B | `Wuhall/Qwen3-14B-LoRA` | 32 | 32 | 514 MB |
#
# Both adapters target: q_proj, k_proj, v_proj, o_proj, gate_proj, up_proj, down_proj
#
# ## Known Issue
#
# **vLLM-neuron 0.4.1** requires every request to include a `lora_request` when `enable_lora=True`.
# Sending a request without one (base model inference) crashes with
# `AttributeError: 'NoneType' object has no attribute 'lora_name'`.
# An internal ticket has been filed and this will be resolved in a future vLLM-neuron release.
# Until then, always pass a `lora_request` with every generate call.

# %% [markdown]
# ## 0. Environment Setup

# %%
# Activate the pre-installed Neuron venv before running this notebook:
# source /opt/aws_neuronx_venv_pytorch_inference_vllm_0_13/bin/activate
# jupyter notebook --no-browser --port=8888

import os
import sys
import time
import json

# Must be set before any vLLM/NxDI imports
os.environ["VLLM_NEURON_FRAMEWORK"] = "neuronx-distributed-inference"
os.environ["VLLM_USE_V1"] = "1"

# Configuration
BASE_MODEL_ID = "Qwen/Qwen3-14B"
BASE_MODEL_DIR = os.path.expanduser("~/Qwen3-14B")
LORA_DIR = os.path.expanduser("~/lora_adapters/qwen3-14b")
ARTIFACT_DIR = os.path.expanduser("~/neuron-artifacts/qwen3-14b-tp4-lora")
HF_REPO = "jburtoft/Qwen3-14B-neuron-trn2-tp4-lora"
HF_TOKEN = os.getenv("HF_TOKEN")  # Set your HF token as an env var

# LoRA adapter repos
LORA_ADAPTERS = {
    "adapter_a": "nicoboss/Qwen3-14B-Uncensored-Lora",
    "adapter_b": "Wuhall/Qwen3-14B-LoRA",
}

# TP=4 on trn2.3xlarge (4 cores at LNC=2, all used for TP)
TP_DEGREE = 4
MAX_MODEL_LEN = 4096
BATCH_SIZE = 1

print(f"Base model: {BASE_MODEL_ID}")
print(f"TP degree: {TP_DEGREE}")
print(f"Artifacts: {ARTIFACT_DIR}")
print(f"LoRA adapters: {list(LORA_ADAPTERS.keys())}")
# Out:
# Base model: Qwen/Qwen3-14B
# TP degree: 4
# Artifacts: /home/ubuntu/neuron-artifacts/qwen3-14b-tp4-lora
# LoRA adapters: ['adapter_a', 'adapter_b']

# %%
# Install dependencies
# !pip install -q huggingface_hub safetensors

# %% [markdown]
# ## 1. Download Model and LoRA Adapters

# %%
from huggingface_hub import snapshot_download, hf_hub_download

# Download base model (~30 GB)
if not os.path.exists(os.path.join(BASE_MODEL_DIR, "config.json")):
    print(f"Downloading {BASE_MODEL_ID}...")
    snapshot_download(
        repo_id=BASE_MODEL_ID,
        local_dir=BASE_MODEL_DIR,
        ignore_patterns=["*.gguf", "*.md", "original/*"],
        token=HF_TOKEN,
    )
    print(f"Downloaded to {BASE_MODEL_DIR}")
else:
    print(f"Base model already exists at {BASE_MODEL_DIR}")
# Out:
# Downloading Qwen/Qwen3-14B...
# Downloaded to /home/ubuntu/Qwen3-14B
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# Fetching 17 files:   6%|▌         | 1/17 [00:00<00:02,  6.57it/s]
# Fetching 17 files:  12%|█▏        | 2/17 [00:01<00:10,  1.40it/s]
# Fetching 17 files:  35%|███▌      | 6/17 [00:53<01:52, 10.27s/it]
# Fetching 17 files:  41%|████      | 7/17 [01:10<01:56, 11.69s/it]
# Fetching 17 files:  47%|████▋     | 8/17 [01:13<01:25,  9.51s/it]
# Fetching 17 files:  53%|█████▎    | 9/17 [01:14<00:59,  7.41s/it]
# Fetching 17 files:  65%|██████▍   | 11/17 [01:14<00:26,  4.38s/it]
# Fetching 17 files: 100%|██████████| 17/17 [01:14<00:00,  4.38s/it]

# %%
# Verify model config
with open(os.path.join(BASE_MODEL_DIR, "config.json")) as f:
    config = json.load(f)

print(f"Model type: {config['model_type']}")
print(f"Hidden size: {config['hidden_size']}")
print(f"Intermediate size: {config['intermediate_size']}")
print(f"Num layers: {config['num_hidden_layers']}")
print(f"Num attention heads: {config['num_attention_heads']}")
print(f"Num KV heads: {config['num_key_value_heads']}")
print(f"Vocab size: {config['vocab_size']}")
print(f"tie_word_embeddings: {config.get('tie_word_embeddings', 'not set')}")

# Qwen3-14B has tie_word_embeddings=false, so no lm_head fix needed
assert config.get("tie_word_embeddings", True) == False, \
    "Expected tie_word_embeddings=False for Qwen3-14B"
# Out:
# Model type: qwen3
# Hidden size: 5120
# Intermediate size: 17408
# Num layers: 40
# Num attention heads: 40
# Num KV heads: 8
# Vocab size: 151936
# tie_word_embeddings: False

# %%
# Download LoRA adapters
os.makedirs(LORA_DIR, exist_ok=True)

for adapter_id, repo_id in LORA_ADAPTERS.items():
    adapter_path = os.path.join(LORA_DIR, adapter_id)
    if os.path.exists(os.path.join(adapter_path, "adapter_config.json")):
        print(f"  {adapter_id} already downloaded")
        continue
    
    print(f"  Downloading {repo_id} -> {adapter_path}")
    os.makedirs(adapter_path, exist_ok=True)
    
    hf_hub_download(
        repo_id=repo_id,
        filename="adapter_config.json",
        local_dir=adapter_path,
        token=HF_TOKEN,
    )
    hf_hub_download(
        repo_id=repo_id,
        filename="adapter_model.safetensors",
        local_dir=adapter_path,
        token=HF_TOKEN,
    )
    print(f"  Downloaded {adapter_id}")

# Verify adapter configs
for adapter_id in LORA_ADAPTERS:
    adapter_path = os.path.join(LORA_DIR, adapter_id)
    with open(os.path.join(adapter_path, "adapter_config.json")) as f:
        acfg = json.load(f)
    print(f"\n{adapter_id}:")
    print(f"  rank: {acfg.get('r', 'N/A')}")
    print(f"  alpha: {acfg.get('lora_alpha', 'N/A')}")
    print(f"  target_modules: {acfg.get('target_modules', 'N/A')}")
    safetensors_path = os.path.join(adapter_path, "adapter_model.safetensors")
    size_mb = os.path.getsize(safetensors_path) / 1024 / 1024
    print(f"  size: {size_mb:.1f} MB")
# Out:
#   adapter_a already downloaded
#   adapter_b already downloaded
#
# adapter_a:
#   rank: 32
#   alpha: 16
#   target_modules: ['gate_proj', 'down_proj', 'o_proj', 'k_proj', 'up_proj', 'v_proj', 'q_proj']
#   size: 490.1 MB
#
# adapter_b:
#   rank: 32
#   alpha: 32
#   target_modules: ['o_proj', 'v_proj', 'k_proj', 'up_proj', 'q_proj', 'gate_proj', 'down_proj']
#   size: 490.1 MB

# %% [markdown]
# ## 2. Create LoRA JSON Config
#
# NxDI requires a JSON file specifying the LoRA adapters. The format is:
# ```json
# {
#     "lora-ckpt-dir": "/path/to/lora_adapters",
#     "lora-ckpt-paths": {
#         "adapter_id": "relative/path/to/adapter"
#     }
# }
# ```
#
# Adapters listed in `lora-ckpt-paths` are loaded into HBM (device memory) at startup.
# Adapters in `lora-ckpt-paths-cpu` are cached in CPU memory for dynamic swapping.

# %%
# Create LoRA config JSON
lora_config = {
    "lora-ckpt-dir": LORA_DIR,
    "lora-ckpt-paths": {
        adapter_id: adapter_id  # relative path under LORA_DIR
        for adapter_id in LORA_ADAPTERS
    },
    "lora-ckpt-paths-cpu": {}  # no CPU-cached adapters for this demo
}

lora_json_path = os.path.join(LORA_DIR, "adapters.json")
with open(lora_json_path, "w") as f:
    json.dump(lora_config, f, indent=2)

print(f"LoRA config written to: {lora_json_path}")
print(json.dumps(lora_config, indent=2))
# Out:
# LoRA config written to: /home/ubuntu/lora_adapters/qwen3-14b/adapters.json
# {
#   "lora-ckpt-dir": "/home/ubuntu/lora_adapters/qwen3-14b",
#   "lora-ckpt-paths": {
#     "adapter_a": "adapter_a",
#     "adapter_b": "adapter_b"
#   },
#   "lora-ckpt-paths-cpu": {}
# }

# %% [markdown]
# ## 3. Compile Model with LoRA
#
# ### NeuronConfig for Qwen3-14B on trn2.3xlarge
#
# - **tp=4**: 14.8 GB model / 4 cores = 3.7 GB/core, with 12.3 GB headroom per 16 GB core
# - **QKV + Attention kernels ON**: ISA kernels improve performance on trn2 at tp=4
# - **MLP kernel OFF**: MLP kernel hurts performance at this scale
# - **LNC=2**: Default on trn2, gives 4 logical NeuronCores with 16 GB HBM each
# - **Qwen3 is natively supported**: `NeuronQwen3ForCausalLM` registered as `qwen3` model type
#
# ### TP Divisibility Check (14B)
#
# | Dimension | Value | /TP=4 | Divides? |
# |-----------|-------|-------|----------|
# | intermediate_size | 17408 | 4352 | Yes |
# | num_attention_heads | 40 | 10 | Yes |
# | num_key_value_heads | 8 | 2 | Yes |
# | hidden_size | 5120 | 1280 | Yes |

# %%
# Neuron config for Qwen3-14B at tp=4, trn2, QKV+Attn kernels ON, MLP OFF
text_neuron_config = {
    "batch_size": BATCH_SIZE,
    "ctx_batch_size": BATCH_SIZE,
    "tkg_batch_size": BATCH_SIZE,
    "seq_len": MAX_MODEL_LEN,
    "max_context_length": MAX_MODEL_LEN,
    "torch_dtype": "bfloat16",
    "tp_degree": TP_DEGREE,
    "world_size": TP_DEGREE,
    "enable_bucketing": True,
    "context_encoding_buckets": [512, 1024, 2048, 4096],
    "token_generation_buckets": [512, 1024, 2048, 4096],
    "fused_qkv": True,
    "qkv_kernel_enabled": True,    # QKV kernel ON for trn2
    "mlp_kernel_enabled": False,    # MLP kernel OFF (hurts at tp=4)
    "attn_kernel_enabled": True,    # Attention kernel ON for trn2
    "logical_neuron_cores": 2,      # trn2 LNC=2 (4 cores)
    "cc_pipeline_tiling_factor": 2, # Match LNC
    "rpl_reduce_dtype": "bfloat16",
    "attention_dtype": "bfloat16",
    "cast_type": "as-declared",
    "save_sharded_checkpoint": True,
}

print("Text neuron config:")
for k, v in text_neuron_config.items():
    print(f"  {k}: {v}")
# Out:
# Text neuron config:
#   batch_size: 1
#   ctx_batch_size: 1
#   tkg_batch_size: 1
#   seq_len: 4096
#   max_context_length: 4096
#   torch_dtype: bfloat16
#   tp_degree: 4
#   world_size: 4
#   enable_bucketing: True
#   context_encoding_buckets: [512, 1024, 2048, 4096]
#   token_generation_buckets: [512, 1024, 2048, 4096]
#   fused_qkv: True
#   qkv_kernel_enabled: True
#   mlp_kernel_enabled: False
#   attn_kernel_enabled: True
#   logical_neuron_cores: 2
#   cc_pipeline_tiling_factor: 2
#   rpl_reduce_dtype: bfloat16
#   attention_dtype: bfloat16
#   cast_type: as-declared
#   save_sharded_checkpoint: True

# %%
# Set artifact directory
os.environ["NEURON_COMPILED_ARTIFACTS"] = ARTIFACT_DIR
os.makedirs(ARTIFACT_DIR, exist_ok=True)

print(f"Artifacts will be saved to: {ARTIFACT_DIR}")
print(f"\nStarting compilation...")
print(f"This will take 10-30 minutes on trn2.3xlarge.")

from vllm import LLM, SamplingParams

compile_start = time.time()

llm = LLM(
    model=BASE_MODEL_DIR,
    tokenizer=BASE_MODEL_DIR,
    trust_remote_code=True,
    dtype="bfloat16",
    tensor_parallel_size=TP_DEGREE,
    max_num_seqs=BATCH_SIZE,
    max_model_len=MAX_MODEL_LEN,
    swap_space=0,
    enable_lora=True,
    max_loras=len(LORA_ADAPTERS),
    max_lora_rank=32,
    additional_config=dict(
        override_neuron_config=dict(
            text_neuron_config=text_neuron_config,
            lora_ckpt_json=lora_json_path,
        )
    ),
    enable_prefix_caching=False,
    enable_chunked_prefill=False,
)

compile_time = time.time() - compile_start
print(f"\nCompilation + loading completed in {compile_time:.1f}s ({compile_time/60:.1f} min)")
# Out:
# Artifacts will be saved to: /home/ubuntu/neuron-artifacts/qwen3-14b-tp4-lora
#
# Starting compilation...
# This will take 10-30 minutes on trn2.3xlarge.
# INFO 03-17 17:20:03 [__init__.py:43] Available plugins for group vllm.platform_plugins:
# INFO 03-17 17:20:03 [__init__.py:45] - neuron -> vllm_neuron:register
# INFO 03-17 17:20:03 [__init__.py:48] All plugins in this group will be loaded. Set `VLLM_PLUGINS` to control which plugins to load.
# INFO 03-17 17:20:03 [__init__.py:217] Platform plugin neuron is activated
# INFO 03-17 17:20:52 [importing.py:44] Triton is installed but 0 active driver(s) found (expected 1). Disabling Triton to prevent runtime errors.
# INFO 03-17 17:20:52 [importing.py:68] Triton not installed or not compatible; certain GPU-related functions will not be available.
# INFO 03-17 17:21:05 [utils.py:253] non-default args: {'tokenizer': '/home/ubuntu/Qwen3-14B', 'trust_remote_code': True, 'dtype': 'bfloat16', 'max_model_len': 4096, 'tensor_parallel_size': 4, 'enable_prefix_caching': False, 'swap_space': 0, 'max_num_seqs': 1, 'disable_log_stats': True, 'enable_lora': True, 'max_loras': 2, 'max_lora_rank': 32, 'enable_chunked_prefill': False, 'additional_config': {'override_neuron_config': {'text_neuron_config': {'batch_size': 1, 'ctx_batch_size': 1, 'tkg_batch_size': 1, 'seq_len': 4096, 'max_context_length': 4096, 'torch_dtype': 'bfloat16', 'tp_degree': 4, 'world_size': 4, 'enable_bucketing': True, 'context_encoding_buckets': [512, 1024, 2048, 4096], 'token_generation_buckets': [512, 1024, 2048, 4096], 'fused_qkv': True, 'qkv_kernel_enabled': True, 'mlp_kernel_enabled': False, 'attn_kernel_enabled': True, 'logical_neuron_cores': 2, 'cc_pipeline_tiling_factor': 2, 'rpl_reduce_dtype': 'bfloat16', 'attention_dtype': 'bfloat16', 'cast_type': 'as-declared', 'save_sharded_checkpoint': True}, 'lora_ckpt_json': '/home/ubuntu/lora_adapters/qwen3-14b/adapters.json'}}, 'model': '/home/ubuntu/Qwen3-14B'}
# WARNING 03-17 17:21:56 [interface.py:221] Failed to import from vllm._C: ImportError('libcuda.so.1: cannot open shared object file: No such file or directory')
# INFO 03-17 17:21:56 [model.py:514] Resolved architecture: Qwen3ForCausalLM
# WARNING 03-17 17:21:56 [arg_utils.py:1869] This model does not officially support disabling chunked prefill. Disabling this manually may cause the engine to crash or produce incorrect outputs.
# INFO 03-17 17:34:23 [llm.py:360] Supported tasks: ['generate']
#
# Compilation + loading completed in 797.3s (13.3 min)
# [2026-03-17 17:21:05] INFO platform.py:108: Applying Neuron config overrides
# [2026-03-17 17:21:05] INFO platform.py:125: Neuron config overrides applied successfully
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# [2026-03-17 17:22:05] INFO platform_overrides.py:22: Skipping attention head divisibility check for Neuron platform
# [2026-03-17 17:22:05] INFO platform.py:167: Neuron OpenAI serving overrides applied successfully
# [2026-03-17 17:22:05] INFO platform.py:272: The custom Neuron scheduler will disable chunked prefill and schedule requests using the continuous batching mechanism, prioritizing prefill over decode.
# [2026-03-17 17:22:05] INFO platform.py:285: Neuron custom scheduler default: max_num_batched_tokens set to 131072. Override with --max-num-batched-tokens if needed.
# [2026-03-17 17:22:06] WARNING platform.py:312: Pin memory is not supported on Neuron.

# %% [markdown]
# ## 4. Verify Inference with LoRA Adapters
#
# Test that the model produces meaningful output with each LoRA adapter.
#
# **Known issue (internal ticket filed):** vLLM-neuron 0.4.1 requires every request to include a
# `lora_request` when `enable_lora=True`. Sending a request without one (i.e., base model inference)
# crashes with `AttributeError: 'NoneType' object has no attribute 'lora_name'`. This will be resolved
# in a future vLLM-neuron release. Until then, always pass a `lora_request` with every generate call.

# %%
from vllm.lora.request import LoRARequest

sampling = SamplingParams(top_k=1, max_tokens=128, temperature=0.0)

test_prompts = [
    "Explain quantum computing in one paragraph.",
    "Write a short Python function that checks if a number is prime.",
    "What are the main differences between TCP and UDP?",
]

# NOTE: Base model (no LoRA) inference is not currently supported when enable_lora=True.
# See known issue note above. All requests must include a lora_request.

# Test with LoRA Adapter A
print("=" * 60)
print(f"ADAPTER A: {LORA_ADAPTERS['adapter_a']}")
print("=" * 60)

lora_req_a = LoRARequest("adapter_a", lora_int_id=1, lora_path=" ")

for prompt in test_prompts:
    t0 = time.time()
    outputs = llm.generate([{"prompt": prompt}], sampling, lora_request=[lora_req_a])
    latency = time.time() - t0
    text = outputs[0].outputs[0].text
    n_tokens = len(outputs[0].outputs[0].token_ids)
    print(f"\nPrompt: {prompt}")
    print(f"Tokens: {n_tokens}, Latency: {latency:.2f}s, Throughput: {n_tokens/latency:.1f} tok/s")
    print(f"Output: {text[:300]}")
    print("-" * 40)
# Out:
# ============================================================
# ADAPTER A: nicoboss/Qwen3-14B-Uncensored-Lora
# ============================================================
#
# Prompt: Explain quantum computing in one paragraph.
# Tokens: 128, Latency: 2.77s, Throughput: 46.2 tok/s
# Output:  Quantum computing is a type of computing that uses quantum-mechanical phenomena, such as superposition and entanglement, to perform operations on data. Unlike classical computers, which use bits as their basic unit of information, quantum computers use qubits, which can exist in multiple states at
# ----------------------------------------
#
# Prompt: Write a short Python function that checks if a number is prime.
# Tokens: 128, Latency: 2.39s, Throughput: 53.7 tok/s
# Output:  The function should return True if the number is prime, and False otherwise. The function should handle edge cases such as numbers less than 2, even numbers, and numbers with multiple factors. The function should be efficient and not use any unnecessary loops or calculations. Here's a Python functi
# ----------------------------------------
#
# Prompt: What are the main differences between TCP and UDP?
# Tokens: 128, Latency: 2.35s, Throughput: 54.4 tok/s
# Output:  Also, could you explain what a socket is in the context of network programming? Additionally, I'm curious about the purpose of the `select()` function in socket programming. How does the `send()` function work in socket programming? What is the difference between `send()` and `write()` in socket pr
# ----------------------------------------
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 103.81it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.76s/it, est. speed input: 2.90 toks/s, output: 46.34 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.76s/it, est. speed input: 2.90 toks/s, output: 46.34 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.76s/it, est. speed input: 2.90 toks/s, output: 46.34 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1575.03it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.38s/it, est. speed input: 5.45 toks/s, output: 53.68 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.38s/it, est. speed input: 5.45 toks/s, output: 53.68 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.38s/it, est. speed input: 5.45 toks/s, output: 53.68 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1552.87it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.35s/it, est. speed input: 4.25 toks/s, output: 54.41 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.35s/it, est. speed input: 4.25 toks/s, output: 54.41 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.35s/it, est. speed input: 4.25 toks/s, output: 54.41 toks/s]

# %%
# Test with LoRA Adapter B
print("=" * 60)
print(f"ADAPTER B: {LORA_ADAPTERS['adapter_b']}")
print("=" * 60)

lora_req_b = LoRARequest("adapter_b", lora_int_id=1, lora_path=" ")

for prompt in test_prompts:
    t0 = time.time()
    outputs = llm.generate([{"prompt": prompt}], sampling, lora_request=[lora_req_b])
    latency = time.time() - t0
    text = outputs[0].outputs[0].text
    n_tokens = len(outputs[0].outputs[0].token_ids)
    print(f"\nPrompt: {prompt}")
    print(f"Tokens: {n_tokens}, Latency: {latency:.2f}s, Throughput: {n_tokens/latency:.1f} tok/s")
    print(f"Output: {text[:300]}")
    print("-" * 40)
# Out:
# ============================================================
# ADAPTER B: Wuhall/Qwen3-14B-LoRA
# ============================================================
#
# Prompt: Explain quantum computing in one paragraph.
# Tokens: 128, Latency: 2.36s, Throughput: 54.3 tok/s
# Output:  Quantum computing is a type of computing that uses the principles of quantum mechanics to perform calculations and process information. Unlike classical computers, which use bits to represent information as either 0 or 1, quantum computers use qubits, which can exist in multiple states at once, all
# ----------------------------------------
#
# Prompt: Write a short Python function that checks if a number is prime.
# Tokens: 128, Latency: 2.40s, Throughput: 53.3 tok/s
# Output:  The function should return True if the number is prime, and False otherwise. The function should handle the case where the number is less than 2 by returning False. The function should also handle the case where the number is 2 by returning True. The function should not use any built-in functions o
# ----------------------------------------
#
# Prompt: What are the main differences between TCP and UDP?
# Tokens: 128, Latency: 2.30s, Throughput: 55.6 tok/s
# Output:  Also, could you explain what a socket is in networking, the purpose of the HTTP protocol, the difference between a GET and POST request in HTTP, and what a firewall is and how it works?
#
# TCP (Transmission Control Protocol) and UDP (User Datagram Protocol) are both transport layer protocols used for
# ----------------------------------------
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 2062.10it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.36s/it, est. speed input: 3.39 toks/s, output: 54.32 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.36s/it, est. speed input: 3.39 toks/s, output: 54.32 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.36s/it, est. speed input: 3.39 toks/s, output: 54.32 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1714.06it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.40s/it, est. speed input: 5.41 toks/s, output: 53.29 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.40s/it, est. speed input: 5.41 toks/s, output: 53.29 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.40s/it, est. speed input: 5.41 toks/s, output: 53.29 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 2001.10it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.30s/it, est. speed input: 4.34 toks/s, output: 55.61 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.30s/it, est. speed input: 4.34 toks/s, output: 55.61 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:02<00:00,  2.30s/it, est. speed input: 4.34 toks/s, output: 55.61 toks/s]

# %% [markdown]
# ## 5. Benchmark Throughput
#
# Run a structured benchmark with multiple prompts to measure steady-state performance.
#
# Only LoRA adapter benchmarks are run (see known issue in Section 4 regarding base model inference).

# %%
import statistics

benchmark_prompts = [
    "Explain the theory of relativity in simple terms.",
    "Write a recursive Fibonacci function in Python with memoization.",
    "What is the difference between a stack and a queue?",
    "Describe the process of photosynthesis.",
    "What are the advantages of microservices architecture?",
    "Explain how a neural network learns through backpropagation.",
    "What is the CAP theorem in distributed systems?",
    "Write a SQL query to find the second highest salary.",
    "Explain the concept of polymorphism in object-oriented programming.",
    "What are the key features of the Rust programming language?",
]

sampling_bench = SamplingParams(top_k=1, max_tokens=256, temperature=0.0)

def run_benchmark(llm, prompts, sampling_params, lora_request, label):
    """Run benchmark with a specific LoRA adapter.
    
    Args:
        lora_request: A LoRARequest object (required -- see known issue in Section 4).
        label: Human-readable label for this benchmark run.
    """
    results = []
    
    # Warmup
    print(f"  Warmup ({label})...")
    llm.generate([{"prompt": prompts[0]}], sampling_params, lora_request=[lora_request])
    
    print(f"  Running {len(prompts)} prompts...")
    for i, prompt in enumerate(prompts):
        t0 = time.time()
        outputs = llm.generate([{"prompt": prompt}], sampling_params, lora_request=[lora_request])
        latency = time.time() - t0
        n_tokens = len(outputs[0].outputs[0].token_ids)
        tok_per_s = n_tokens / latency if latency > 0 else 0
        results.append({
            "prompt_idx": i,
            "n_tokens": n_tokens,
            "latency_s": round(latency, 3),
            "tok_per_s": round(tok_per_s, 1),
        })
    
    throughputs = [r["tok_per_s"] for r in results]
    latencies = [r["latency_s"] for r in results]
    tokens = [r["n_tokens"] for r in results]
    
    summary = {
        "label": label,
        "num_prompts": len(prompts),
        "mean_throughput_tok_s": round(statistics.mean(throughputs), 1),
        "std_throughput_tok_s": round(statistics.stdev(throughputs), 1) if len(throughputs) > 1 else 0,
        "mean_latency_s": round(statistics.mean(latencies), 2),
        "mean_tokens": round(statistics.mean(tokens), 0),
        "total_tokens": sum(tokens),
        "total_time_s": round(sum(latencies), 1),
        "results": results,
    }
    
    print(f"\n  [{label}] Results:")
    print(f"    Mean throughput: {summary['mean_throughput_tok_s']:.1f} +/- {summary['std_throughput_tok_s']:.1f} tok/s")
    print(f"    Mean latency:   {summary['mean_latency_s']:.2f}s")
    print(f"    Mean tokens:    {summary['mean_tokens']:.0f}")
    print(f"    Total tokens:   {summary['total_tokens']}")
    print(f"    Total time:     {summary['total_time_s']:.1f}s")
    
    return summary

print("Starting benchmarks...\n")
# Out:
# Starting benchmarks...

# %%
# Benchmark: Adapter A
print("=" * 60)
print(f"BENCHMARK: Adapter A ({LORA_ADAPTERS['adapter_a']})")
print("=" * 60)
lora_req_a = LoRARequest("adapter_a", lora_int_id=1, lora_path=" ")
results_a = run_benchmark(llm, benchmark_prompts, sampling_bench, lora_request=lora_req_a, label="Adapter A")
# Out:
# ============================================================
# BENCHMARK: Adapter A (nicoboss/Qwen3-14B-Uncensored-Lora)
# ============================================================
#   Warmup (Adapter A)...
#   Running 10 prompts...
#
#   [Adapter A] Results:
#     Mean throughput: 54.6 +/- 1.6 tok/s
#     Mean latency:   4.69s
#     Mean tokens:    256
#     Total tokens:   2560
#     Total time:     46.9s
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1403.25it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.65s/it, est. speed input: 2.37 toks/s, output: 55.11 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.65s/it, est. speed input: 2.37 toks/s, output: 55.11 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.65s/it, est. speed input: 2.37 toks/s, output: 55.11 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 2139.95it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.55s/it, est. speed input: 2.42 toks/s, output: 56.29 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.55s/it, est. speed input: 2.42 toks/s, output: 56.29 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.55s/it, est. speed input: 2.42 toks/s, output: 56.29 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1330.68it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.71s/it, est. speed input: 2.33 toks/s, output: 54.33 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.71s/it, est. speed input: 2.33 toks/s, output: 54.33 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.71s/it, est. speed input: 2.33 toks/s, output: 54.33 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1428.58it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.87s/it, est. speed input: 2.26 toks/s, output: 52.53 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.87s/it, est. speed input: 2.26 toks/s, output: 52.53 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.87s/it, est. speed input: 2.26 toks/s, output: 52.53 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1491.57it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.88s/it, est. speed input: 1.43 toks/s, output: 52.42 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.88s/it, est. speed input: 1.43 toks/s, output: 52.42 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.88s/it, est. speed input: 1.43 toks/s, output: 52.42 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1481.56it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.84s/it, est. speed input: 1.86 toks/s, output: 52.94 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.84s/it, est. speed input: 1.86 toks/s, output: 52.94 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.84s/it, est. speed input: 1.86 toks/s, output: 52.94 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1298.95it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.72s/it, est. speed input: 2.54 toks/s, output: 54.23 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.72s/it, est. speed input: 2.54 toks/s, output: 54.23 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.72s/it, est. speed input: 2.54 toks/s, output: 54.23 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1398.57it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.62s/it, est. speed input: 1.95 toks/s, output: 55.36 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.62s/it, est. speed input: 1.95 toks/s, output: 55.36 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.62s/it, est. speed input: 1.95 toks/s, output: 55.36 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1343.90it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.52s/it, est. speed input: 2.43 toks/s, output: 56.64 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.52s/it, est. speed input: 2.43 toks/s, output: 56.64 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.52s/it, est. speed input: 2.43 toks/s, output: 56.64 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1295.74it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it, est. speed input: 2.63 toks/s, output: 56.04 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it, est. speed input: 2.63 toks/s, output: 56.04 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it, est. speed input: 2.63 toks/s, output: 56.04 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1385.63it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it, est. speed input: 2.41 toks/s, output: 56.04 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it, est. speed input: 2.41 toks/s, output: 56.04 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it, est. speed input: 2.41 toks/s, output: 56.04 toks/s]

# %%
# Benchmark: Adapter B
print("=" * 60)
print(f"BENCHMARK: Adapter B ({LORA_ADAPTERS['adapter_b']})")
print("=" * 60)
lora_req_b = LoRARequest("adapter_b", lora_int_id=1, lora_path=" ")
results_b = run_benchmark(llm, benchmark_prompts, sampling_bench, lora_request=lora_req_b, label="Adapter B")
# Out:
# ============================================================
# BENCHMARK: Adapter B (Wuhall/Qwen3-14B-LoRA)
# ============================================================
#   Warmup (Adapter B)...
#   Running 10 prompts...
#
#   [Adapter B] Results:
#     Mean throughput: 55.9 +/- 0.4 tok/s
#     Mean latency:   4.58s
#     Mean tokens:    256
#     Total tokens:   2560
#     Total time:     45.8s
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 2000.14it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.58s/it, est. speed input: 2.40 toks/s, output: 55.86 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.58s/it, est. speed input: 2.40 toks/s, output: 55.86 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.58s/it, est. speed input: 2.40 toks/s, output: 55.86 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1946.31it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.61s/it, est. speed input: 2.39 toks/s, output: 55.58 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.61s/it, est. speed input: 2.39 toks/s, output: 55.58 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.61s/it, est. speed input: 2.39 toks/s, output: 55.58 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 2043.01it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.60s/it, est. speed input: 2.39 toks/s, output: 55.67 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.60s/it, est. speed input: 2.39 toks/s, output: 55.67 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.60s/it, est. speed input: 2.39 toks/s, output: 55.67 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1879.17it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.60s/it, est. speed input: 2.39 toks/s, output: 55.65 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.60s/it, est. speed input: 2.39 toks/s, output: 55.65 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.60s/it, est. speed input: 2.39 toks/s, output: 55.65 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1888.48it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.54s/it, est. speed input: 1.54 toks/s, output: 56.35 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.54s/it, est. speed input: 1.54 toks/s, output: 56.35 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.54s/it, est. speed input: 1.54 toks/s, output: 56.35 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1854.25it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.63s/it, est. speed input: 1.95 toks/s, output: 55.35 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.63s/it, est. speed input: 1.95 toks/s, output: 55.35 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.63s/it, est. speed input: 1.95 toks/s, output: 55.35 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1978.45it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.58s/it, est. speed input: 2.62 toks/s, output: 55.94 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.58s/it, est. speed input: 2.62 toks/s, output: 55.94 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.58s/it, est. speed input: 2.62 toks/s, output: 55.94 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 2117.27it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it, est. speed input: 1.97 toks/s, output: 56.03 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it, est. speed input: 1.97 toks/s, output: 56.03 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it, est. speed input: 1.97 toks/s, output: 56.03 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 2081.54it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.53s/it, est. speed input: 2.43 toks/s, output: 56.55 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.53s/it, est. speed input: 2.43 toks/s, output: 56.55 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.53s/it, est. speed input: 2.43 toks/s, output: 56.55 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1934.64it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.60s/it, est. speed input: 2.61 toks/s, output: 55.61 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.60s/it, est. speed input: 2.61 toks/s, output: 55.61 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.60s/it, est. speed input: 2.61 toks/s, output: 55.61 toks/s]
#
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Adding requests: 100%|██████████| 1/1 [00:00<00:00, 1945.41it/s]
#
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it, est. speed input: 2.41 toks/s, output: 55.97 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it, est. speed input: 2.41 toks/s, output: 55.97 toks/s]
# Processed prompts: 100%|██████████| 1/1 [00:04<00:00,  4.57s/it, est. speed input: 2.41 toks/s, output: 55.97 toks/s]

# %%
# Summary table
print("\n" + "=" * 70)
print("BENCHMARK SUMMARY: Qwen3-14B on trn2.3xlarge, tp=4, BF16")
print("=" * 70)
print(f"{'Config':<20} {'Throughput (tok/s)':>20} {'Latency (s)':>15} {'Tokens':>10}")
print("-" * 70)

for r in [results_a, results_b]:
    print(f"{r['label']:<20} {r['mean_throughput_tok_s']:>17.1f} +/- {r['std_throughput_tok_s']:<5.1f} {r['mean_latency_s']:>12.2f}s {r['mean_tokens']:>10.0f}")

print("-" * 70)
print(f"\nConfiguration:")
print(f"  Instance: trn2.3xlarge (4 NeuronCores at LNC=2)")
print(f"  TP: {TP_DEGREE}, Batch size: {BATCH_SIZE}")
print(f"  Max model len: {MAX_MODEL_LEN}")
print(f"  Precision: BF16, ISA kernels: QKV+Attn ON, MLP OFF")
print(f"  LNC: 2, cc_pipeline_tiling_factor: 2")
print(f"  Compile time: {compile_time:.0f}s")
print(f"\nNote: Base model (no LoRA) benchmarks not available due to known vLLM-neuron issue.")
print(f"See Section 4 for details. Internal ticket filed.")
# Out:
# ======================================================================
# BENCHMARK SUMMARY: Qwen3-14B on trn2.3xlarge, tp=4, BF16
# ======================================================================
# Config                 Throughput (tok/s)     Latency (s)     Tokens
# ----------------------------------------------------------------------
# Adapter A                         54.6 +/- 1.6           4.69s        256
# Adapter B                         55.9 +/- 0.4           4.58s        256
# ----------------------------------------------------------------------
#
# Configuration:
#   Instance: trn2.3xlarge (4 NeuronCores at LNC=2)
#   TP: 4, Batch size: 1
#   Max model len: 4096
#   Precision: BF16, ISA kernels: QKV+Attn ON, MLP OFF
#   LNC: 2, cc_pipeline_tiling_factor: 2
#   Compile time: 797s
#
# Note: Base model (no LoRA) benchmarks not available due to known vLLM-neuron issue.
# See Section 4 for details. Internal ticket filed.

# %%
# Save results to JSON
results_path = os.path.expanduser("~/qwen3_14b_lora_results.json")
all_results = {
    "config": {
        "model": BASE_MODEL_ID,
        "instance": "trn2.3xlarge",
        "tp_degree": TP_DEGREE,
        "batch_size": BATCH_SIZE,
        "max_model_len": MAX_MODEL_LEN,
        "precision": "bfloat16",
        "isa_kernels": "qkv+attn_on_mlp_off",
        "lnc": 2,
        "cc_pipeline_tiling_factor": 2,
        "compile_time_s": compile_time,
        "lora_adapters": LORA_ADAPTERS,
        "note": "base model (no LoRA) cannot be tested -- vLLM-neuron requires lora_request when enable_lora=True",
    },
    "results": {
        "adapter_a": {k: v for k, v in results_a.items() if k != "results"},
        "adapter_b": {k: v for k, v in results_b.items() if k != "results"},
    },
    "detailed_results": {
        "adapter_a": results_a["results"],
        "adapter_b": results_b["results"],
    },
}

with open(results_path, "w") as f:
    json.dump(all_results, f, indent=2)

print(f"Results saved to {results_path}")
# Out:
# Results saved to /home/ubuntu/qwen3_14b_lora_results.json

# %% [markdown]
# ## 6. Check and Upload Artifacts
#
# Verify the compiled artifacts and upload to HuggingFace for reuse on fresh instances.

# %%
# Check saved artifacts
print(f"Artifact directory: {ARTIFACT_DIR}\n")

total_size = 0
for root, dirs, files in os.walk(ARTIFACT_DIR):
    for f in files:
        fpath = os.path.join(root, f)
        size = os.path.getsize(fpath)
        total_size += size
        rel = os.path.relpath(fpath, ARTIFACT_DIR)
        print(f"  {rel:65s} {size / 1024 / 1024:8.1f} MB")

print(f"\n  TOTAL: {total_size / 1024 / 1024 / 1024:.2f} GB")

# Check for sharded weights
has_text_weights = os.path.exists(os.path.join(ARTIFACT_DIR, "text_model", "weights"))
print(f"\n  Pre-sharded weights: {'YES' if has_text_weights else 'NO'}")
# Out:
# Artifact directory: /home/ubuntu/neuron-artifacts/qwen3-14b-tp4-lora
#
#   model.pt                                                             240.3 MB
#   neuron_config.json                                                     0.0 MB
#
#   TOTAL: 0.23 GB
#
#   Pre-sharded weights: NO

# %%
# Free model memory before upload
del llm
import gc
gc.collect()
print("Model freed from memory.")
# Out:
# Model freed from memory.

# %%
from huggingface_hub import HfApi

api = HfApi(token=HF_TOKEN)

# Create repo
api.create_repo(repo_id=HF_REPO, repo_type="model", exist_ok=True)
print(f"Created repo: {HF_REPO}")

# Upload artifacts
print(f"Uploading artifacts from {ARTIFACT_DIR}...")
print(f"This may take several minutes for ~{total_size / 1024 / 1024 / 1024:.1f} GB of data.")

upload_start = time.time()
api.upload_folder(
    folder_path=ARTIFACT_DIR,
    repo_id=HF_REPO,
    path_in_repo="bs1_tp4",
    repo_type="model",
)
upload_time = time.time() - upload_start
print(f"Artifacts uploaded in {upload_time:.0f}s")

# Upload LoRA adapters (so they're available with the artifacts)
print("Uploading LoRA adapters...")
api.upload_folder(
    folder_path=LORA_DIR,
    repo_id=HF_REPO,
    path_in_repo="lora_adapters",
    repo_type="model",
)

# Upload results
api.upload_file(
    path_or_fileobj=results_path,
    path_in_repo="benchmark_results.json",
    repo_id=HF_REPO,
    repo_type="model",
)

print(f"\nAll uploads complete: https://huggingface.co/{HF_REPO}")
# Out:
# Created repo: jburtoft/Qwen3-14B-neuron-trn2-tp4-lora
# Uploading artifacts from /home/ubuntu/neuron-artifacts/qwen3-14b-tp4-lora...
# This may take several minutes for ~0.2 GB of data.
# Artifacts uploaded in 9s
# Uploading LoRA adapters...
#
# All uploads complete: https://huggingface.co/jburtoft/Qwen3-14B-neuron-trn2-tp4-lora
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
#
# New Data Upload               : |          |  0.00B /  0.00B
#
#
#   ...en3-14b-tp4-lora/model.pt:   0%|          | 1.14MB /  252MB
#
#
#   ...en3-14b-tp4-lora/model.pt:   0%|          | 1.14MB /  252MB
# Processing Files (0 / 1)      :   0%|          | 1.14MB /  252MB, 1.42MB/s
#
# New Data Upload               :   1%|          | 1.09MB /  134MB, 1.36MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:   1%|          | 2.28MB /  252MB
# Processing Files (0 / 1)      :   1%|          | 2.28MB /  252MB, 2.28MB/s
#
# New Data Upload               :   2%|▏         | 2.18MB /  134MB, 2.18MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:   3%|▎         | 6.84MB /  252MB
# Processing Files (0 / 1)      :   3%|▎         | 6.84MB /  252MB, 5.69MB/s
#
# New Data Upload               :   5%|▍         | 6.53MB /  134MB, 5.44MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:   4%|▍         | 10.3MB /  252MB
# Processing Files (0 / 1)      :   4%|▍         | 10.3MB /  252MB, 7.32MB/s
#
# New Data Upload               :   7%|▋         | 9.79MB /  134MB, 6.99MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:   9%|▉         | 23.9MB /  252MB
# Processing Files (0 / 1)      :   9%|▉         | 23.9MB /  252MB, 15.0MB/s
#
# New Data Upload               :  17%|█▋        | 22.8MB /  134MB, 14.3MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  17%|█▋        | 42.2MB /  252MB
# Processing Files (0 / 1)      :  17%|█▋        | 42.2MB /  252MB, 23.4MB/s
#
# New Data Upload               :  30%|██▉       | 40.3MB /  134MB, 22.4MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  21%|██        | 52.4MB /  252MB
# Processing Files (0 / 1)      :  21%|██        | 52.4MB /  252MB, 26.2MB/s
#
# New Data Upload               :  37%|███▋      | 50.0MB /  134MB, 25.0MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  27%|██▋       | 67.2MB /  252MB
# Processing Files (0 / 1)      :  27%|██▋       | 67.2MB /  252MB, 30.5MB/s
#
# New Data Upload               :  48%|████▊     | 64.2MB /  134MB, 29.2MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  28%|██▊       | 69.5MB /  252MB
# Processing Files (0 / 1)      :  28%|██▊       | 69.5MB /  252MB, 29.0MB/s
#
# New Data Upload               :  49%|████▉     | 66.4MB /  134MB, 27.6MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  28%|██▊       | 69.5MB /  252MB
#
#
#   ...en3-14b-tp4-lora/model.pt:  28%|██▊       | 71.1MB /  252MB
# Processing Files (0 / 1)      :  28%|██▊       | 71.1MB /  252MB, 25.4MB/s
#
# New Data Upload               :  50%|█████     | 67.1MB /  134MB, 24.0MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  28%|██▊       | 71.1MB /  252MB
#
#
#   ...en3-14b-tp4-lora/model.pt:  28%|██▊       | 71.1MB /  252MB
#
#
#   ...en3-14b-tp4-lora/model.pt:  36%|███▌      | 91.3MB /  252MB
# Processing Files (0 / 1)      :  36%|███▌      | 91.3MB /  252MB, 26.8MB/s
#
# New Data Upload               :  51%|█████     | 68.2MB /  134MB, 20.0MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  44%|████▍     |  111MB /  252MB
# Processing Files (0 / 1)      :  44%|████▍     |  111MB /  252MB, 30.8MB/s
#
# New Data Upload               :  34%|███▍      | 69.2MB /  203MB, 19.2MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  47%|████▋     |  119MB /  252MB
# Processing Files (0 / 1)      :  47%|████▋     |  119MB /  252MB, 31.2MB/s
#
# New Data Upload               :  38%|███▊      | 77.1MB /  203MB, 20.3MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  51%|█████     |  128MB /  252MB
# Processing Files (0 / 1)      :  51%|█████     |  128MB /  252MB, 31.9MB/s
#
# New Data Upload               :  43%|████▎     | 86.1MB /  203MB, 21.5MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  57%|█████▋    |  144MB /  252MB
# Processing Files (0 / 1)      :  57%|█████▋    |  144MB /  252MB, 34.4MB/s
#
# New Data Upload               :  51%|█████     |  103MB /  203MB, 24.4MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  65%|██████▌   |  165MB /  252MB
# Processing Files (0 / 1)      :  65%|██████▌   |  165MB /  252MB, 37.4MB/s
#
# New Data Upload               :  61%|██████    |  123MB /  203MB, 28.0MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  74%|███████▍  |  187MB /  252MB
# Processing Files (0 / 1)      :  74%|███████▍  |  187MB /  252MB, 40.6MB/s
#
# New Data Upload               :  72%|███████▏  |  145MB /  203MB, 31.6MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  82%|████████▏ |  205MB /  252MB
# Processing Files (0 / 1)      :  82%|████████▏ |  205MB /  252MB, 42.8MB/s
#
# New Data Upload               :  81%|████████  |  164MB /  203MB, 34.1MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  87%|████████▋ |  220MB /  252MB
# Processing Files (0 / 1)      :  87%|████████▋ |  220MB /  252MB, 44.1MB/s
#
# New Data Upload               :  88%|████████▊ |  179MB /  203MB, 35.8MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  91%|█████████ |  229MB /  252MB
# Processing Files (0 / 1)      :  91%|█████████ |  229MB /  252MB, 43.9MB/s
#
# New Data Upload               :  92%|█████████▏|  187MB /  203MB, 35.9MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  94%|█████████▍|  238MB /  252MB
# Processing Files (0 / 1)      :  94%|█████████▍|  238MB /  252MB, 44.0MB/s
#
# New Data Upload               :  97%|█████████▋|  196MB /  203MB, 36.3MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  97%|█████████▋|  244MB /  252MB
# Processing Files (0 / 1)      :  97%|█████████▋|  244MB /  252MB, 43.5MB/s
#
# New Data Upload               : 100%|█████████▉|  202MB /  203MB, 36.1MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  97%|█████████▋|  244MB /  252MB
#
#
#   ...en3-14b-tp4-lora/model.pt:  97%|█████████▋|  244MB /  252MB
#
#
#   ...en3-14b-tp4-lora/model.pt:  97%|█████████▋|  244MB /  252MB
#
#
#   ...en3-14b-tp4-lora/model.pt:  97%|█████████▋|  244MB /  252MB
#
#
#   ...en3-14b-tp4-lora/model.pt:  97%|█████████▋|  244MB /  252MB
# Processing Files (0 / 1)      :  97%|█████████▋|  244MB /  252MB, 37.0MB/s
#
# New Data Upload               : 100%|██████████|  203MB /  203MB, 30.7MB/s
#
#
#   ...en3-14b-tp4-lora/model.pt:  97%|█████████▋|  244MB /  252MB
#
#
#   ...en3-14b-tp4-lora/model.pt:  97%|█████████▋|  244MB /  252MB
#
#
#   ...en3-14b-tp4-lora/model.pt:  97%|█████████▋|  244MB /  252MB
# Processing Files (0 / 1)      :  97%|█████████▋|  244MB /  252MB, 34.9MB/s
#
# New Data Upload               : 100%|██████████|  203MB /  203MB, 28.9MB/s
#
#   ...en3-14b-tp4-lora/model.pt:  97%|█████████▋|  244MB /  252MB
#
# Processing Files (0 / 0)      : |          |  0.00B /  0.00B
#
# New Data Upload               : |          |  0.00B /  0.00B
#
#
#   ...adapter_model.safetensors:   1%|▏         | 6.50MB /  514MB
#
#
#
#   ...adapter_model.safetensors:   7%|▋         | 36.9MB /  514MB
#
#
#   ...adapter_model.safetensors:   1%|▏         | 6.50MB /  514MB
#
#
#
#   ...adapter_model.safetensors:   7%|▋         | 36.9MB /  514MB
# Processing Files (0 / 2)      :   4%|▍         | 43.4MB / 1.03GB,  108MB/s
#
#
#   ...adapter_model.safetensors:   1%|▏         | 6.50MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  28%|██▊       |  146MB /  514MB
# Processing Files (0 / 2)      :  15%|█▍        |  153MB / 1.03GB,  255MB/s
#
#
#   ...adapter_model.safetensors:   1%|▏         | 6.50MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  50%|█████     |  257MB /  514MB
# Processing Files (0 / 2)      :  26%|██▌       |  264MB / 1.03GB,  330MB/s
#
#
#   ...adapter_model.safetensors:  13%|█▎        | 65.9MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  70%|███████   |  361MB /  514MB
# Processing Files (0 / 2)      :  42%|████▏     |  427MB / 1.03GB,  428MB/s
#
#
#   ...adapter_model.safetensors:  32%|███▏      |  164MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  91%|█████████▏|  470MB /  514MB
# Processing Files (0 / 2)      :  62%|██████▏   |  634MB / 1.03GB,  528MB/s
#
#
#   ...adapter_model.safetensors:  32%|███▏      |  164MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
# Processing Files (0 / 2)      :  62%|██████▏   |  636MB / 1.03GB,  454MB/s
#
#
#   ...adapter_model.safetensors:  57%|█████▋    |  292MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
# Processing Files (0 / 2)      :  74%|███████▍  |  764MB / 1.03GB,  477MB/s
#
#
#   ...adapter_model.safetensors:  80%|████████  |  412MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
# Processing Files (0 / 2)      :  86%|████████▌ |  884MB / 1.03GB,  491MB/s
#
#
#   ...adapter_model.safetensors:  88%|████████▊ |  454MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
# Processing Files (0 / 2)      :  90%|█████████ |  926MB / 1.03GB,  463MB/s
#
#
#   ...adapter_model.safetensors:  89%|████████▉ |  458MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
# Processing Files (0 / 2)      :  90%|█████████ |  929MB / 1.03GB,  423MB/s
#
# New Data Upload               :   4%|▍         | 3.92MB /  102MB, 1.78MB/s
#
#
#   ...adapter_model.safetensors:  89%|████████▉ |  458MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
#
#
#   ...adapter_model.safetensors:  89%|████████▉ |  458MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
#
#
#   ...adapter_model.safetensors:  89%|████████▉ |  458MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
#
#
#   ...adapter_model.safetensors:  90%|████████▉ |  462MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
# Processing Files (0 / 2)      :  91%|█████████ |  933MB / 1.03GB,  311MB/s
#
# New Data Upload               :   8%|▊         | 7.85MB /  102MB, 2.62MB/s
#
#
#   ...adapter_model.safetensors:  91%|█████████▏|  469MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
# Processing Files (0 / 2)      :  92%|█████████▏|  941MB / 1.03GB,  294MB/s
#
# New Data Upload               :  15%|█▍        | 15.1MB /  102MB, 4.73MB/s
#
#
#   ...adapter_model.safetensors:  93%|█████████▎|  478MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
# Processing Files (0 / 2)      :  92%|█████████▏|  949MB / 1.03GB,  279MB/s
#
# New Data Upload               :  23%|██▎       | 23.5MB /  102MB, 6.93MB/s
#
#
#   ...adapter_model.safetensors:  94%|█████████▍|  482MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
# Processing Files (0 / 2)      :  93%|█████████▎|  954MB / 1.03GB,  265MB/s
#
# New Data Upload               :  27%|██▋       | 28.0MB /  102MB, 7.79MB/s
#
#
#   ...adapter_model.safetensors:  96%|█████████▌|  491MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
# Processing Files (0 / 2)      :  94%|█████████▎|  963MB / 1.03GB,  253MB/s
#
# New Data Upload               :  36%|███▌      | 37.0MB /  102MB, 9.74MB/s
#
#
#   ...adapter_model.safetensors:  97%|█████████▋|  500MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
# Processing Files (0 / 2)      :  95%|█████████▍|  972MB / 1.03GB,  243MB/s
#
# New Data Upload               :  45%|████▍     | 46.0MB /  102MB, 11.5MB/s
#
#
#   ...adapter_model.safetensors:  99%|█████████▉|  509MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
# Processing Files (0 / 2)      :  95%|█████████▌|  980MB / 1.03GB,  233MB/s
#
# New Data Upload               :  53%|█████▎    | 54.4MB /  102MB, 13.0MB/s
#
#
#   ...adapter_model.safetensors: 100%|█████████▉|  513MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
# Processing Files (0 / 2)      :  96%|█████████▌|  984MB / 1.03GB,  224MB/s
#
# New Data Upload               :  58%|█████▊    | 58.9MB /  102MB, 13.4MB/s
#
#
#   ...adapter_model.safetensors: 100%|█████████▉|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
# Processing Files (0 / 2)      :  96%|█████████▌|  985MB / 1.03GB,  214MB/s
#
# New Data Upload               :  58%|█████▊    | 59.4MB /  102MB, 12.9MB/s
#
#
#   ...adapter_model.safetensors: 100%|█████████▉|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
#
#
#   ...adapter_model.safetensors: 100%|█████████▉|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
#
#
#   ...adapter_model.safetensors: 100%|█████████▉|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
#
#
#   ...adapter_model.safetensors: 100%|█████████▉|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  471MB /  514MB
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  475MB /  514MB
# Processing Files (1 / 2)      :  96%|█████████▌|  989MB / 1.03GB,  177MB/s
#
# New Data Upload               :  62%|██████▏   | 63.6MB /  102MB, 11.4MB/s
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  92%|█████████▏|  475MB /  514MB
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  94%|█████████▍|  483MB /  514MB
# Processing Files (1 / 2)      :  97%|█████████▋|  997MB / 1.03GB,  166MB/s
#
# New Data Upload               :  70%|███████   | 71.5MB /  102MB, 11.9MB/s
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  96%|█████████▌|  492MB /  514MB
# Processing Files (1 / 2)      :  98%|█████████▊| 1.01GB / 1.03GB,  162MB/s
#
# New Data Upload               :  78%|███████▊  | 80.0MB /  102MB, 12.9MB/s
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  97%|█████████▋|  501MB /  514MB
# Processing Files (1 / 2)      :  99%|█████████▊| 1.01GB / 1.03GB,  159MB/s
#
# New Data Upload               :  87%|████████▋ | 89.1MB /  102MB, 13.9MB/s
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors:  98%|█████████▊|  505MB /  514MB
# Processing Files (1 / 2)      :  99%|█████████▉| 1.02GB / 1.03GB,  154MB/s
#
# New Data Upload               :  91%|█████████ | 93.0MB /  102MB, 14.1MB/s
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors: 100%|█████████▉|  514MB /  514MB
# Processing Files (1 / 2)      : 100%|█████████▉| 1.03GB / 1.03GB,  151MB/s
#
# New Data Upload               : 100%|█████████▉|  102MB /  102MB, 15.0MB/s
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors: 100%|█████████▉|  514MB /  514MB
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors: 100%|█████████▉|  514MB /  514MB
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors: 100%|█████████▉|  514MB /  514MB
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
# Processing Files (2 / 2)      : 100%|██████████| 1.03GB / 1.03GB,  135MB/s
#
# New Data Upload               : 100%|██████████|  102MB /  102MB, 13.4MB/s
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
# Processing Files (2 / 2)      : 100%|██████████| 1.03GB / 1.03GB,  125MB/s
#
# New Data Upload               : 100%|██████████|  102MB /  102MB, 12.5MB/s
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB
#
#   ...adapter_model.safetensors: 100%|██████████|  514MB /  514MB

# %%
# Upload model card
model_card = f"""---
tags:
- neuron
- aws
- trn2
- trainium2
- qwen3
- lora
- pre-compiled
library_name: neuronx-distributed-inference
---

# Qwen3-14B with LoRA -- Pre-compiled for AWS Trainium2

Pre-compiled artifacts for running [Qwen/Qwen3-14B](https://huggingface.co/Qwen/Qwen3-14B)
with LoRA adapters on AWS Trainium2 (trn2.3xlarge).

## Configuration

| Setting | Value |
|---------|-------|
| Instance type | trn2.3xlarge (4 NeuronCores at LNC=2) |
| Tensor parallel | 4 |
| Batch size | 1 |
| Max sequence length | {MAX_MODEL_LEN} |
| Data type | BF16 |
| ISA Kernels | QKV+Attn ON, MLP OFF |
| LNC | 2 |
| Compile time | {{compile_time:.0f}}s |
| SDK | Neuron SDK 2.28 (DLAMI 20260227) |
| NxD Inference | 0.8.x |
| vLLM-neuron | 0.4.1 |

## Benchmark Results

| Config | Throughput (tok/s) | Latency (s) | Avg Tokens |
|--------|-------------------|-------------|------------|
| Adapter A (nicoboss/Uncensored) | {{results_a['mean_throughput_tok_s']:.1f}} +/- {{results_a['std_throughput_tok_s']:.1f}} | {{results_a['mean_latency_s']:.2f}} | {{results_a['mean_tokens']:.0f}} |
| Adapter B (Wuhall/LoRA) | {{results_b['mean_throughput_tok_s']:.1f}} +/- {{results_b['std_throughput_tok_s']:.1f}} | {{results_b['mean_latency_s']:.2f}} | {{results_b['mean_tokens']:.0f}} |

## Included LoRA Adapters

| Adapter | Source | Rank | Alpha | Target Modules |
|---------|--------|------|-------|---------------|
| adapter_a | nicoboss/Qwen3-14B-Uncensored-Lora | 32 | 16 | q/k/v/o/gate/up/down_proj |
| adapter_b | Wuhall/Qwen3-14B-LoRA | 32 | 32 | q/k/v/o/gate/up/down_proj |

## Important Notes

1. **Base model weights required**: Download `Qwen/Qwen3-14B` separately (~30 GB).
2. **LoRA always required**: When `enable_lora=True`, every request MUST include a `lora_request`. Omitting it causes `AttributeError`. Internal ticket filed.
3. **trn2.3xlarge required**: tp=4 needs 4 NeuronCores (LNC=2 default).
4. **SDK-specific**: Artifacts work with Neuron SDK 2.28 (DLAMI 20260227) only.
5. **Update LoRA paths**: The `lora-ckpt-dir` in `adapters.json` must be an absolute path matching your local layout.
"""

api.upload_file(
    path_or_fileobj=model_card.encode(),
    path_in_repo="README.md",
    repo_id=HF_REPO,
    repo_type="model",
)

print(f"Model card uploaded to https://huggingface.co/{HF_REPO}")
# Out:
# Model card uploaded to https://huggingface.co/jburtoft/Qwen3-14B-neuron-trn2-tp4-lora

# %% [markdown]
# ## 7. Summary
#
# ### What we accomplished
#
# 1. Compiled Qwen3-14B (14.8B params, BF16) on trn2.3xlarge at tp=4 with ISA kernels (QKV+Attn)
# 2. Integrated two LoRA adapters (rank=32) via NxDI's LoRA serving
# 3. Benchmarked both adapters (base model benchmarks not available due to known vLLM-neuron issue)
# 4. Uploaded pre-compiled artifacts to HuggingFace for instant deployment
#
# ### Key findings
#
# - **tp=4 on trn2.3xlarge**: Uses all 4 NeuronCores at LNC=2, 16 GB HBM per core
# - **ISA kernels**: QKV + Attention kernels enabled for better performance on Trainium2
# - **Pre-compilation workflow**: Compile once, deploy anywhere (same SDK + instance type)
# - **Known issue**: Base model inference (no LoRA) not supported when `enable_lora=True` in vLLM-neuron 0.4.1. Internal ticket filed.
#
# ### Comparison with inf2.24xlarge
#
# | Instance | Throughput (tok/s) | Compile Time | ISA Kernels | Cost |
# |----------|-------------------|-------------|-------------|------|
# | inf2.24xlarge | 27.5 | ~12.5 min | All OFF | On-demand |
# | trn2.3xlarge | TBD | TBD | QKV+Attn ON | Capacity block / Spot |

# %%
print("Done! Notebook execution complete.")
print(f"\nArtifacts available at: https://huggingface.co/{HF_REPO}")
print(f"Benchmark results saved to: {results_path}")
# Out:
# Done! Notebook execution complete.
#
# Artifacts available at: https://huggingface.co/jburtoft/Qwen3-14B-neuron-trn2-tp4-lora
# Benchmark results saved to: /home/ubuntu/qwen3_14b_lora_results.json
